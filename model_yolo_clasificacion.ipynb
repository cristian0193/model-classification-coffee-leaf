# %%
from ultralytics import YOLO

model = YOLO("yolo11n-cls.pt")

results = model.train(data="../model-classification-coffee-leaf/dataset_yolo_cls", epochs=20, batch=32, imgsz=640, device=0)
# Out:
# Ultralytics 8.3.139  Python-3.12.7 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4070 Ti, 12282MiB)
# ...

# %%
model_pred = YOLO("../runs/classify/train/weights/best.pt")

results = model_pred(source="../model-classification-coffee-leaf/dataset_yolo_cls/test/miner")
# Out:
# image 1/128 d:\Maestria\2-Cursos\9-TFM\Recursos\Fuente\model-classification-coffee-leaf\..\model-classification-coffee-leaf\dataset_yolo_cls\test\miner\1100.jpg: 640x640 miner 1.00, phoma 0.00, nodisease 0.00, rust 0.00, 2.6ms
# image 2/128 d:\Maestria\2-Cursos\9-TFM\Recursos\Fuente\model-classification-coffee-leaf\..\model-classification-coffee-leaf\dataset_yolo_cls\test\miner\1101.jpg: 640x640 miner 1.00, phoma 0.00, nodisease 0.00, rust 0.00, 2.5ms
# image 3/128 d:\Maestria\2-Cursos\9-TFM\Recursos\Fuente\model-classification-coffee-leaf\..\model-classification-coffee-leaf\dataset_yolo_cls\test\miner\1102.jpg: 640x640 miner 1.00, phoma 0.00, nodisease 0.00, rust 0.00, 2.3ms
# image 4/128 d:\Maestria\2-Cursos\9-TFM\Recursos\Fuente\model-classification-coffee-leaf\..\model-classification-coffee-leaf\dataset_yolo_cls\test\miner\1103.jpg: 640x640 miner 1.00, phoma 0.00, nodisease 0.00, rust 0.00, 2.3ms
# ...

# %%
from IPython.display import display
from PIL import Image

img_array = results[0].plot(boxes=False)
pil_img = Image.fromarray(img_array)

display(pil_img)
# Out:
# <PIL.Image.Image image mode=RGB size=2048x1024>
